# %%
from history_loader import HistoryLoader
from spark_and_table_setup import spark

# %%
loader = HistoryLoader(spark)

# %%
loader.load_history()
# Out:
# Starting historical data load ...
# Doneing date_lookup table...
# Historical data load completed in 20 seconds

# %%
spark.sql("select * from sbit_db.date_lookup").show()
# Out:
# +----------+----+----+-----+---------+----------+---------+---------+
# |      date|week|year|month|dayofweek|dayofmonth|dayofyear|week_part|
# +----------+----+----+-----+---------+----------+---------+---------+
# |2023-01-01|   1|2023|    1|        1|         1|        1|   2023-1|
# |2023-01-02|   1|2023|    1|        2|         2|        2|   2023-1|
# |2023-01-03|   1|2023|    1|        3|         3|        3|   2023-1|
# |2023-01-04|   1|2023|    1|        4|         4|        4|   2023-1|
# |2023-01-05|   1|2023|    1|        5|         5|        5|   2023-1|
# |2023-01-06|   1|2023|    1|        6|         6|        6|   2023-1|
# |2023-01-07|   1|2023|    1|        7|         7|        7|   2023-1|
# |2023-01-08|   2|2023|    1|        1|         8|        8|   2023-2|
# |2023-01-09|   2|2023|    1|        2|         9|        9|   2023-2|
# |2023-01-10|   2|2023|    1|        3|        10|       10|   2023-2|
# |2023-01-11|   2|2023|    1|        4|        11|       11|   2023-2|
# |2023-01-12|   2|2023|    1|        5|        12|       12|   2023-2|
# |2023-01-13|   2|2023|    1|        6|        13|       13|   2023-2|
# |2023-01-14|   2|2023|    1|        7|        14|       14|   2023-2|
# |2023-01-15|   3|2023|    1|        1|        15|       15|   2023-3|
# |2023-01-16|   3|2023|    1|        2|        16|       16|   2023-3|
# |2023-01-17|   3|2023|    1|        3|        17|       17|   2023-3|
# |2023-01-18|   3|2023|    1|        4|        18|       18|   2023-3|
# |2023-01-19|   3|2023|    1|        5|        19|       19|   2023-3|
# |2023-01-20|   3|2023|    1|        6|        20|       20|   2023-3|
# +----------+----+----+-----+---------+----------+---------+---------+
# only showing top 20 rows
