# %%
from spark_and_table_setup import spark
# Out:
# Starting setup ...
# Doneting the database sbit_db...
# Created: data_zone/raw/gym_logins_bz
# Created: data_zone/raw/kafka_multiplex_bz
# Created: data_zone/raw/registered_users_bz
# Doneting registered_users_bz table...
# Doneting gym_logins_bz table...
# Doneting kafka_multiplex_bz table...
# Doneting users table...
# Doneting gym_logs table...
# Doneting user_profile table...
# Doneting heart_rate table...
# Doneting workouts table...
# Doneting completed_workouts table...
# Doneting workout_bpm table...
# Doneting user_bins table...
# Doneting date_lookup table...
# Doneting workout_bpm_summary table...
# Doneting gym_summar gold view...
# Setup completed in 24 seconds

# %%
spark.sql("show databases").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# |  sbit_db|
# +---------+

# %%
#spark.conf.set("spark.sql.shuffle.partitions", sc.defaultParallelism)
spark.conf.set("spark.databricks.delta.optimizeWrite.enabled", True)
spark.conf.set("spark.databricks.delta.autoCompact.enabled", True)
#spark.conf.set("spark.sql.streaming.stateStore.providerClass", "com.databricks.sql.streaming.state.RocksDBStateStoreProvider")

# %%
from producer import Producer
PR =Producer(spark)
PR.produce(1)
PR.validate(1)
# Out:
# Producing test data set 1 ...
# Producing data_zone/test_data/1-registered_users_1.csv...Done
# Producing data_zone/test_data/2-user_info_1.json...Done
# Producing data_zone/test_data/4-workout_1.json...Done
# Producing data_zone/test_data/5-gym_logins_1.csv...Done
# Doneucing data_zone/test_data/3-bpm_1.json...
# Test data set 1 produced in 0 seconds
#
# Validating test data 1 sets...
# Found 5 / Expected 5 records: Successstered_users...
# Found 7 / Expected 7 records: Successinfo...
# Found 253,801 / Expected 253,801 records: Success
# Found 16 / Expected 16 records: Success...
# Found 8 / Expected 8 records: Success...

# %%
from run_all_layers import RunAllLayers
RAL = RunAllLayers(spark)

# %%
RAL.execute()
# Out:
# Starting bronze layer consumption ...
# Completed bronze layer consumtion 45 seconds
#
# Executing silver layer upsert ...
# Completed silver layer 1 upsert 136 seconds
# Completed silver layer 2 upsert 195 seconds
# Completed silver layer 3 upsert 244 seconds
#
# Executing gold layer upsert ...
# Completed gold layer upsert 23 seconds

# %%
RAL.validate_first_ingestion()
# Out:
# Validating bronz layer records...
# Found 5 / Expected 5 records where true: Success..
# Found 8 / Expected 8 records where true: Success
# Found 7 / Expected 7 records where topic='user_info': Success
# Found 16 / Expected 16 records where topic='workout': Success
# Found 253,801 / Expected 253,801 records where topic='bpm': Success
# Bronze layer validation completed in 4 seconds
#
# Validating silver layer records...
# Found 5 / Expected 5 records where true: Success
# Found 8 / Expected 8 records where true: Success
# Found 5 / Expected 5 records where true: Success
# Found 16 / Expected 16 records where true: Success
# Found 253,801 / Expected 253,801 records where true: Success
# Found 5 / Expected 5 records where true: Success
# Found 8 / Expected 8 records where true: Success.
# Found 3,968 / Expected 3,968 records where true: Success
# Silver layer validation completed in 6 seconds
#
# Validating gold layer records...
# Expected data matches with the actual data in gym_summary: Success
# Gold layer validation completed in 2 seconds

# %%
from producer import Producer
PR =Producer(spark)
PR.produce(2)
PR.validate(2)
# Out:
# Producing test data set 2 ...
# Producing data_zone/test_data/1-registered_users_2.csv...Done
# Producing data_zone/test_data/2-user_info_2.json...Done
# Producing data_zone/test_data/4-workout_2.json...Done
# Producing data_zone/test_data/5-gym_logins_2.csv...Done
# Doneucing data_zone/test_data/3-bpm_2.json...
# Test data set 2 produced in 0 seconds
#
# Validating test data 2 sets...
# Found 10 / Expected 10 records: Successered_users...
# Validating kafka_multiplex_bz/2-user_info...Found 13 / Expected 13 records: Success
# Found 507,602 / Expected 507,602 records: Success
# Found 32 / Expected 32 records: Success...
# Found 16 / Expected 16 records: Success.

# %%
RAL.execute()
# Out:
# Starting bronze layer consumption ...
# Completed bronze layer consumtion 17 seconds
#
# Executing silver layer upsert ...
# Completed silver layer 1 upsert 98 seconds
# Completed silver layer 2 upsert 145 seconds
# Completed silver layer 3 upsert 191 seconds
#
# Executing gold layer upsert ...
# Completed gold layer upsert 24 seconds

# %%
RAL.validate_second_ingestion()
# Out:
# Validating bronz layer records...
# Found 10 / Expected 10 records where true: Success
# Found 16 / Expected 16 records where true: Success
# Found 13 / Expected 13 records where topic='user_info': Success
# Found 32 / Expected 32 records where topic='workout': Success
# Found 507,602 / Expected 507,602 records where topic='bpm': Success
# Bronze layer validation completed in 3 seconds
#
# Validating silver layer records...
# Found 10 / Expected 10 records where true: Success
# Found 16 / Expected 16 records where true: Success
# Found 10 / Expected 10 records where true: Success
# Found 32 / Expected 32 records where true: Success
# Found 507,602 / Expected 507,602 records where true: Success
# Found 10 / Expected 10 records where true: Success
# Found 16 / Expected 16 records where true: Success
# Found 8,192 / Expected 8,192 records where true: Success
# Silver layer validation completed in 6 seconds
#
# Validating gold layer records...
# Expected data matches with the actual data in gym_summary: Success
# Found 2 / Expected 2 records where true: Success..
# Gold layer validation completed in 4 seconds
