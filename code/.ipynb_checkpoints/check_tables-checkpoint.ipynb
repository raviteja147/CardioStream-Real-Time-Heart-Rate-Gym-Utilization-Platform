# %%
from spark_and_table_setup import spark

# %%
spark.sql("select * from sbit_db.date_lookup").show(2)
# Out:
# +----------+----+----+-----+---------+----------+---------+---------+
# |      date|week|year|month|dayofweek|dayofmonth|dayofyear|week_part|
# +----------+----+----+-----+---------+----------+---------+---------+
# |2023-01-01|   1|2023|    1|        1|         1|        1|   2023-1|
# |2023-01-02|   1|2023|    1|        2|         2|        2|   2023-1|
# +----------+----+----+-----+---------+----------+---------+---------+
# only showing top 2 rows

# %%
spark.sql("select * from sbit_db.registered_users_bz").show(2)
# Out:
# +-------+---------+-----------------+----------------------+--------------------+--------------------+
# |user_id|device_id|      mac_address|registration_timestamp|           load_time|         source_file|
# +-------+---------+-----------------+----------------------+--------------------+--------------------+
# |  12474|   118440|4c:c5:9f:cb:13:bd|         1.678451168E9|2025-09-15 02:12:...|file:///home/jupy...|
# |  12140|   141687|ae:ec:f6:48:ca:f7|         1.678451529E9|2025-09-15 02:12:...|file:///home/jupy...|
# +-------+---------+-----------------+----------------------+--------------------+--------------------+
# only showing top 2 rows

# %%
spark.sql("select * from sbit_db.gym_logins_bz").show(2)
# Out:
# +-----------------+---+-----------+-----------+--------------------+--------------------+
# |      mac_address|gym|      login|     logout|           load_time|         source_file|
# +-----------------+---+-----------+-----------+--------------------+--------------------+
# |4c:c5:9f:cb:13:bd|  5|1.6785216E9|1.6785261E9|2025-09-15 02:12:...|file:///home/jupy...|
# |ae:ec:f6:48:ca:f7|  1|1.6785225E9|1.6785252E9|2025-09-15 02:12:...|file:///home/jupy...|
# +-----------------+---+-----------+-----------+--------------------+--------------------+
# only showing top 2 rows

# %%
spark.sql("select * from sbit_db.kafka_multiplex_bz").show(2)
# Out:
# +-----+--------------------+-------+---------+------+----------+----+---------+--------------------+--------------------+
# |  key|               value|  topic|partition|offset| timestamp|date|week_part|           load_time|         source_file|
# +-----+--------------------+-------+---------+------+----------+----+---------+--------------------+--------------------+
# |12474|{"user_id": 12474...|workout|        0|190099|1678521900|null|     null|2025-09-15 02:12:...|file:///home/jupy...|
# |12140|{"user_id": 12140...|workout|        0|190592|1678522800|null|     null|2025-09-15 02:12:...|file:///home/jupy...|
# +-----+--------------------+-------+---------+------+----------+----+---------+--------------------+--------------------+
# only showing top 2 rows

# %%
spark.sql("select * from sbit_db.users").show(2)
# Out:
# +-------+---------+-----------------+----------------------+
# |user_id|device_id|      mac_address|registration_timestamp|
# +-------+---------+-----------------+----------------------+
# |  12227|   114131|57:24:ac:8c:75:ea|   2023-03-10 12:40:28|
# |  11745|   190960|14:cd:d6:db:70:f6|   2023-03-10 12:34:41|
# +-------+---------+-----------------+----------------------+
# only showing top 2 rows

# %%
spark.sql("select * from sbit_db.gym_logs").show(2)
# Out:
# +-----------------+---+-------------------+-------------------+
# |      mac_address|gym|              login|             logout|
# +-----------------+---+-------------------+-------------------+
# |14:cd:d6:db:70:f6|  5|2023-03-11 19:20:00|2023-03-11 20:15:00|
# |57:24:ac:8c:75:ea|  5|2023-03-11 19:28:00|2023-03-11 20:40:00|
# +-----------------+---+-------------------+-------------------+
# only showing top 2 rows

# %%
spark.sql("select count(*) from sbit_db.user_profile").show(2)
# Out:
# +--------+
# |count(1)|
# +--------+
# |       0|
# +--------+

# %%
spark.sql("select count(*) from sbit_db.workouts").show(2)
# Out:
# +--------+
# |count(1)|
# +--------+
# |       0|
# +--------+

# %%
spark.sql("select count(*) from sbit_db.heart_rate").show(2)
# Out:
# +--------+
# |count(1)|
# +--------+
# |       0|
# +--------+

# %%
spark.sql("select count(*) from sbit_db.user_bins").show(2)
# Out:
# +--------+
# |count(1)|
# +--------+
# |       0|
# +--------+

# %%
spark.sql("select count(*) from sbit_db.completed_workouts").show(2)
# Out:
# +--------+
# |count(1)|
# +--------+
# |       0|
# +--------+

# %%
spark.sql("select count(*) from sbit_db.workout_bpm").show(2)
# Out:
# +--------+
# |count(1)|
# +--------+
# |       0|
# +--------+

# %%
spark.sql("select * from sbit_db.workout_bpm_summary").show()
# Out:
# +----------+----------+-------+---+------+----+-----+-------+-------+-------+--------------+
# |workout_id|session_id|user_id|age|gender|city|state|min_bpm|avg_bpm|max_bpm|num_recordings|
# +----------+----------+-------+---+------+----+-----+-------+-------+-------+--------------+
# +----------+----------+-------+---+------+----+-----+-------+-------+-------+--------------+

# %%
spark.sql("select * from sbit_db.gym_summary").show(2)
# Out:
# +----+---+-----------+----------+----------+--------------+------------------+
# |date|gym|mac_address|workout_id|session_id|minutes_in_gym|minutes_exercising|
# +----+---+-----------+----------+----------+--------------+------------------+
# +----+---+-----------+----------+----------+--------------+------------------+
