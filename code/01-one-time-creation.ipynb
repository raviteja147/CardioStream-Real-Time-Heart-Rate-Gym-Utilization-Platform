# %%
from spark_session import get_spark
from setup_helper import SetupHelper

# %%
spark = get_spark("SBIT")
helper = SetupHelper(spark)

# %%
helper.cleanup()
helper.setup()
helper.validate()
# Out:
# data_zone/raw deleted successfully
# spark-warehouse/ deleted successfully
#
# Starting setup validation ...
# Found database sbit_db: Success
# Found registered_users_bz table in sbit_db: Success
# Found gym_logins_bz table in sbit_db: Success
# Found kafka_multiplex_bz table in sbit_db: Success
# Found users table in sbit_db: Success
# Found gym_logs table in sbit_db: Success
# Found user_profile table in sbit_db: Success
# Found heart_rate table in sbit_db: Success
# Found workouts table in sbit_db: Success
# Found completed_workouts table in sbit_db: Success
# Found workout_bpm table in sbit_db: Success
# Found user_bins table in sbit_db: Success
# Found date_lookup table in sbit_db: Success
# Found workout_bpm_summary table in sbit_db: Success
# Found gym_summary table in sbit_db: Success
# Setup validation completed in 2 seconds

# %%
spark.sql("show databases").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# |  sbit_db|
# +---------+
